# %% [markdown]
# ## Assignment GDP Analysis
# <i><b> Author:</b> <u>Anish Mahapatra</u></i>
# <i><b>Email-id:</b> anishmahapatra01@gmail.com </i>
#
# ##### Upgrad Module 09 - Assignment: GDP Analysis
#
# The purpose of this the overall GDP Analysis is to help identify areas to focus on that will foster economic development for the respective states. This will be done by analyzing the GDP.
#
# <b>GDP:</b> Monetary value of final goods and services produced by a country/state in a given period of time. It mostly consists of the following three sectors:
# - Primary sector (agriculture)
# - Secondary sector (industry)
# - Tertiary sector (services)
#
# In the <b>first part</b> of the analysis, the following steps will be taken care of:
# - the GSDP of Indian States - both total and per capita will be analyzed
# - The States will be divided into 4 cases on the basis of GSDP analysis
# - Post categorizaion, analysis will be done to identify the sectors that contribute the most to GDP
#
# In the <b>second part</b> of the analysis, we shall analyze whether GDP per capita is related to dropout rates in schools and colleges.
#
# Let's go!

# %% [markdown]
# ## Data Loading - Data1, GSDP, Data2

# %%
#Importing the required modules and packages

import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
import pandas as pd
import numpy as np
import glob, os

pd.set_option('display.max_columns', 500)

# %%
# Filling in the path variable to pick up the .csv files from the 'Data Folder'
# This is just the GSDP data
path = './Data/*.csv'

# Reading all the paths to the csv files and initializing an empty list
all_files = glob.glob(path)
allFilesList = []

# For loop to ingest all csv files, transpose the data and append the same onto a master datatset

for filename in all_files:
    # Reading each file into a pandas dataframe with 'latin' encoding
    df = pd.read_csv(filename, encoding = 'latin', index_col = None, header = 0)
    
    # Transposing the data using transpose() function
    df = df.transpose()
    
    # Removing the first row that contains the headers from df
    new_header = df.iloc[0]
    df = df[1:]
    
    # Making first row as column
    df.columns = new_header
    
    # Getting the name of the state to add it as a new column in the master dataset
    df['State'] = filename.split('\\')[-1].split('.')[0]
    allFilesList.append(df)
    
# Concatenating the data into the master dataset called dfGSDP
dfStatesGDP = pd.concat(allFilesList, axis = 0, ignore_index = True)

# %%
# Sense check of master dataset of State's GDP
dfStatesGDP
# Out:
# S.No.                                  1       1.1        1.2  \
# 0      Agriculture, forestry and fishing     Crops  Livestock
# 1                                9400805   5204052    2758776
# 2                               11186428   6123041    3358438
# 3                               12895568   7114707    3643026
# 4                               14819416   7893514    4309078
# 5                               17326726   8644285    5155487
# 6                               20386004   9717089    5979648
# 7      Agriculture, forestry and fishing     Crops  Livestock
# 8                                 455505    255815      29657
# 9                                 545406    331962      24249
# 10                                603944    360344      34027
# 11                                686117    415520      38387
# 12                                744726    431318      44386
# 13     Agriculture, forestry and fishing     Crops  Livestock
# 14                               2848113   2061487     159289
# 15                               3391548   2496905     179160
# 16                               3692959   2720261     155267
# 17                               3855548   2890544     173478
# 18                               4343564   3310990     175526
# 19     Agriculture, forestry and fishing     Crops  Livestock
# 20                               6206655   4260778    1202821
# 21                               7669989   5336544    1481102
# 22                               7371939   4522339    1831596
# 23                               7951890   4688237    2060296
# 24                               8095024   4577220    2247038
# 25     Agriculture, forestry and fishing     Crops  Livestock
# 26                               2685950   1798258     226704
# 27                               3180908   2140927     255035
# 28                               3589934   2395705     310931
# 29                               3948847   2613371     352208
# ..                                   ...       ...        ...
# 132                              8773221   5375639    2617944
# 133                              8439666   4696306    2972027
# 134                             10867130   6294046    3738883
# 135                             13064238   7297820    4693361
# 136                             13143892   7280028    4765971
# 137                             13707951   7557588    4995138
# 138    Agriculture, forestry and fishing     Crops  Livestock
# 139                              5461488   3236819    1884801
# 140                              6726490   4057031    2278539
# 141                              7723553   4715888    2539923
# 142                              7591501   4162493    2951299
# 143                              7755281   3867873    3436285
# 144                              9216180   4885862    3852198
# 145    Agriculture, forestry and fishing     Crops  Livestock
# 146                               511201    318959      33664
# 147                               567087    339064      42223
# 148                               702979    375086      70541
# 149                               799825    397591      88176
# 150    Agriculture, forestry and fishing     Crops  Livestock
# 151                             18324305  12415418    4382274
# 152                             21306497  14951864    4687592
# 153                             23813650  16249998    5908922
# 154                             25097754  16215212    7096876
# 155                             28212490  18242114    8233666
# 156    Agriculture, forestry and fishing     Crops  Livestock
# 157                          1.33021e+06    764026     287787
# 158                          1.53664e+06    901730     313744
# 159                           1.5791e+06    850163     351373
# 160                          1.60142e+06    866146     391188
# 161                          1.71504e+06    893917     447222
#
# S.No.                   1.3                      1.4                     2  \
# 0      Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 1                    250314                  1187663               1416194
# 2                    253029                  1451920               1459027
# 3                    280493                  1857342               1419200
# 4                    346160                  2270664               1484300
# 5                    340550                  3186404               1633100
# 6                    335487                  4353780               1757565
# 7      Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 8                    165510                     4523                 23022
# 9                    183780                     5415                 35024
# 10                   204038                     5535                 43616
# 11                   224017                     8193                 30842
# 12                   258676                    10346                 38068
# 13     Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 14                   231388                   395949               1464989
# 15                   246368                   469115               1448306
# 16                   311458                   505973               1423477
# 17                   261987                   529539               1471149
# 18                   278521                   578527               1493456
# 19     Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 20                   418682                   324374                 19858
# 21                   457077                   395266                 23429
# 22                   500976                   517028                150804
# 23                   550132                   653224                 68107
# 24                   591042                   679725                 68549
# 25     Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 26                   426205                   234783               1970258
# 27                   503309                   281637               1923021
# 28                   559637                   323661               2144358
# 29                   597785                   385483               2451970
# ..                      ...                      ...                   ...
# 132                  355528                   424110                326843
# 133                  338087                   433247                317889
# 134                  399307                   434895                318743
# 135                  392705                   680352                265536
# 136                  415952                   681941                261638
# 137                  434416                   720809                276321
# 138    Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 139                  191725                   148143               1106109
# 140                  207059                   183861               1268476
# 141                  218021                   249721               1238555
# 142                  210741                   266968               1541853
# 143                  213338                   237785               1723849
# 144                  210850                   267270               1889245
# 145    Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 146                  109763                    48815                118123
# 147                  119262                    66538                128413
# 148                  133116                   124236                130634
# 149                  145096                   168961                142391
# 150    Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 151                 1249516                   277097                653517
# 152                 1358583                   308458                688795
# 153                 1312393                   342337                868920
# 154                 1404936                   380730                901501
# 155                 1330196                   406514                783973
# 156    Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 157                  274833                     3562                186083
# 158                  317354                     3815                205726
# 159                  373062                     4497                354844
# 160                  339293                     4796                244549
# 161                  368781                     5119                298187
#
# S.No.        Total              3  \
# 0          Primary  Manufacturing
# 1         10816999        5070622
# 2         12645455        4237657
# 3         14314768        4242337
# 4         16303716        4672266
# 5         18959826        5078685
# 6         22143569        5740816
# 7          Primary  Manufacturing
# 8           478527          12900
# 9           580430          14827
# 10          647560          19714
# 11          716959          26120
# 12          782794          37743
# 13         Primary  Manufacturing
# 14         4313102        1540255
# 15         4839854        1531538
# 16         5116436        1904299
# 17         5326697        2002936
# 18         5837020        2055341
# 19         Primary  Manufacturing
# 20         6226513        1466570
# 21         7693418        1035092
# 22         7522743        2120942
# 23         8019997        2189965
# 24         8163574        2892956
# 25         Primary  Manufacturing
# 26         4656208        2435032
# 27         5103929        2817915
# 28         5734292        3810105
# 29         6400817        4370593
# ..             ...            ...
# 132        9100064       15176801
# 133        8757555       17826090
# 134       11185873       18137892
# 135       13329774       18914794
# 136       13405530       20142365
# 137       13984272       21026591
# 138        Primary  Manufacturing
# 139        6567597        6215158
# 140        7994966        5543115
# 141        8962108        5714839
# 142        9133354        6353711
# 143        9479130        6677750
# 144       11105425        7323500
# 145        Primary  Manufacturing
# 146         629324          72651
# 147         695500         117529
# 148         833613         125869
# 149         942216         228625
# 150        Primary  Manufacturing
# 151       18977822        8763582
# 152       21995292        9522404
# 153       24682570       11377466
# 154       25999255       12261649
# 155       28996463       13604096
# 156        Primary  Manufacturing
# 157    1.51629e+06    4.36514e+06
# 158    1.74237e+06     5.0829e+06
# 159    1.93394e+06    5.43926e+06
# 160    1.84597e+06    5.86625e+06
# 161    2.01323e+06    6.13256e+06
#
# S.No.                                                  4             5  \
# 0      Electricity, gas, water supply & other utility...  Construction
# 1                                                1076517       3702645
# 2                                                 713029       3759004
# 3                                                1014130       4065131
# 4                                                1151729       4664889
# 5                                                1251910       4986189
# 6                                                1298947       5467732
# 7      Electricity, gas, water supply & other utility...  Construction
# 8                                                  69131        104529
# 9                                                  78766        107821
# 10                                                 89594        124594
# 11                                                113527        147842
# 12                                                139187        161705
# 13     Electricity, gas, water supply & other utility...  Construction
# 14                                                191883       1188747
# 15                                                210901       1270304
# 16                                                257083       1537481
# 17                                                296587       1733568
# 18                                                372236       2093594
# 19     Electricity, gas, water supply & other utility...  Construction
# 20                                                365887       2701685
# 21                                                442206       2781005
# 22                                                385931       3184760
# 23                                                345168       3449763
# 24                                                363130       3667664
# 25     Electricity, gas, water supply & other utility...  Construction
# 26                                                709991       1901330
# 27                                                970686       1920771
# 28                                               1051772       2260022
# 29                                               1198438       2669855
# ..                                                   ...           ...
# 132                                               795604       9247221
# 133                                              1267240      10235650
# 134                                              1303592      11418102
# 135                                              1710379      12216718
# 136                                              2073838      13395808
# 137                                              2336516      14533745
# 138    Electricity, gas, water supply & other utility...  Construction
# 139                                               783505       2278975
# 140                                               589605       2357786
# 141                                               870938       2458242
# 142                                               716266       2854024
# 143                                               661426       3030401
# 144                                               666068       3395388
# 145    Electricity, gas, water supply & other utility...  Construction
# 146                                                44297        148327
# 147                                                55855        151630
# 148                                                55022        174411
# 149                                                77870        177899
# 150    Electricity, gas, water supply & other utility...  Construction
# 151                                               926846       8487701
# 152                                              1228906       9320623
# 153                                              1663539      10048635
# 154                                              2030625      11256450
# 155                                              2152779      12225841
# 156    Electricity, gas, water supply & other utility...  Construction
# 157                                               398079        883766
# 158                                               416111        936950
# 159                                               375058   1.24305e+06
# 160                                               433880   1.34273e+06
# 161                                               541284     1.833e+06
#
# S.No.        Total                                      6  \
# 0        Secondary  Trade, repair, hotels and restaurants
# 1          9849784                                2673600
# 2          8709690                                3179200
# 3          9321598                                3784900
# 4         10488884                                4233400
# 5         11316784                                4577700
# 6         12507496                                5174600
# 7        Secondary  Trade, repair, hotels and restaurants
# 8           186560                                  59892
# 9           201414                                  50878
# 10          233902                                  70494
# 11          287489                                  60421
# 12          338635                                  65846
# 13       Secondary  Trade, repair, hotels and restaurants
# 14         2920885                                2045676
# 15         3012743                                2284041
# 16         3698863                                2573962
# 17         4033091                                2987155
# 18         4521171                                3480621
# 19       Secondary  Trade, repair, hotels and restaurants
# 20         4534142                                4390442
# 21         4258302                                5175534
# 22         5691633                                5205102
# 23         5984896                                7448373
# 24         6923750                                8789191
# 25       Secondary  Trade, repair, hotels and restaurants
# 26         5046354                                 932617
# 27         5709372                                1101271
# 28         7121899                                1288982
# 29         8238886                                1535571
# ..             ...                                    ...
# 132       25219626                                7930219
# 133       29328980                                9691628
# 134       30859585                               11344765
# 135       32841892                               12895842
# 136       35612011                               14567728
# 137       37896853                               15372472
# 138      Secondary  Trade, repair, hotels and restaurants
# 139        9277638                                3747813
# 140        8490506                                4454669
# 141        9044019                                5127458
# 142        9924001                                6494607
# 143       10369577                                7481535
# 144       11384956                                8786776
# 145      Secondary  Trade, repair, hotels and restaurants
# 146         265275                                 226839
# 147         325014                                 265292
# 148         355302                                 333695
# 149         484393                                 390423
# 150      Secondary  Trade, repair, hotels and restaurants
# 151       18178129                                6946589
# 152       20071933                                7472500
# 153       23089640                                8713200
# 154       25548724                                9437243
# 155       27982716                               10603082
# 156      Secondary  Trade, repair, hotels and restaurants
# 157    5.64698e+06                             1.1929e+06
# 158    6.43596e+06                            1.40887e+06
# 159    7.05737e+06                            1.61458e+06
# 160    7.64286e+06                            1.74311e+06
# 161    8.50685e+06                             1.9916e+06
#
# S.No.                      6.1                   6.2  \
# 0      Trade & repair services  Hotels & restaurants
# 1                      2322700                350900
# 2                      2775600                403600
# 3                      3290800                494100
# 4                      3716000                517400
# 5                      3964000                613700
# 6                      4382200                792400
# 7      Trade & repair services  Hotels & restaurants
# 8                        56921                  2971
# 9                        47880                  2998
# 10                       67273                  3221
# 11                       56796                  3625
# 12                       62044                  3802
# 13     Trade & repair services  Hotels & restaurants
# 14                     1961211                 84465
# 15                     2191727                 92314
# 16                     2473790                100172
# 17                     2876251                110904
# 18                     3353852                126769
# 19     Trade & repair services  Hotels & restaurants
# 20                     4110861                279581
# 21                     4867227                308307
# 22                     4873547                331555
# 23                     7081391                366982
# 24                     8383018                406173
# 25     Trade & repair services  Hotels & restaurants
# 26                      847597                 85020
# 27                     1011450                 89821
# 28                     1178419                110563
# 29                     1414164                121407
# ..                         ...                   ...
# 132                    6893400               1036819
# 133                    8505165               1186463
# 134                    9967754               1377011
# 135                   11252588               1643253
# 136                   12593468               1974260
# 137                   13171329               2201143
# 138    Trade & repair services  Hotels & restaurants
# 139                    3048685                699128
# 140                    3647224                807445
# 141                    4456270                671188
# 142                    5724128                770479
# 143                    6634722                846813
# 144                    7841875                944901
# 145    Trade & repair services  Hotels & restaurants
# 146                     226839                   NaN
# 147                     265292                   NaN
# 148                     333695                   NaN
# 149                     390423                   NaN
# 150    Trade & repair services  Hotels & restaurants
# 151                    6162196                784393
# 152                    6641138                831362
# 153                    7723813                989387
# 154                    8476139                961104
# 155                    9523247               1079835
# 156    Trade & repair services  Hotels & restaurants
# 157                  1.014e+06                178899
# 158                1.21882e+06                190047
# 159                1.42669e+06                187883
# 160                1.53407e+06                209033
# 161                1.76822e+06                223381
#
# S.No.                                                  7       7.1  \
# 0      Transport, storage, communication & services r...  Railways
# 1                                                3251379    264279
# 2                                                3778632    303702
# 3                                                4365811    334468
# 4                                                5076984    424228
# 5                                                5806226    436596
# 6                                                6766317    445372
# 7      Transport, storage, communication & services r...  Railways
# 8                                                  23420        30
# 9                                                  27306        34
# 10                                                 33414        47
# 11                                                 35203        59
# 12                                                 42833        65
# 13     Transport, storage, communication & services r...  Railways
# 14                                                810091    158334
# 15                                                929196    186316
# 16                                               1086729    215234
# 17                                               1194568    252509
# 18                                               1392834    294682
# 19     Transport, storage, communication & services r...  Railways
# 20                                               1754480    275142
# 21                                               2161629    334829
# 22                                               2684993    395681
# 23                                               3147173    462413
# 24                                               3658194    540400
# 25     Transport, storage, communication & services r...  Railways
# 26                                                583708    121509
# 27                                                683320    140418
# 28                                                783315    150098
# 29                                                871770    159176
# ..                                                   ...       ...
# 132                                              5337904    316026
# 133                                              6145938    370416
# 134                                              6726593    401984
# 135                                              7188320    468553
# 136                                              8008838    548315
# 137                                              8780319    581276
# 138    Transport, storage, communication & services r...  Railways
# 139                                              2531735    161363
# 140                                              2987019    175620
# 141                                              3229811    193048
# 142                                              3604741    199686
# 143                                              4182002    205940
# 144                                              4895352    208823
# 145    Transport, storage, communication & services r...  Railways
# 146                                                84316       224
# 147                                               108895       261
# 148                                               121265       261
# 149                                               155956       305
# 150    Transport, storage, communication & services r...  Railways
# 151                                              4048142   1066108
# 152                                              4919874   1227911
# 153                                              6102126   1398344
# 154                                              7404509   1618742
# 155                                              8079924   1534567
# 156    Transport, storage, communication & services r...  Railways
# 157                                               703706     14140
# 158                                               825647     16514
# 159                                               951652     17214
# 160                                          1.06669e+06     21295
# 161                                          1.22423e+06     24470
#
# S.No.              7.2              7.3            7.4  \
# 0       Road transport  Water transport  Air transport
# 1              1824800            95100           4500
# 2              2200400            90400          10600
# 3              2516200            60600           5100
# 4              2816000            94200          14900
# 5              3217400           110500          25000
# 6              3798300           123600          28000
# 7       Road transport  Water transport  Air transport
# 8                12382                0              0
# 9                13618                0              0
# 10               16059                0              0
# 11               15467                0              0
# 12               20413                0              0
# 13      Road transport  Water transport  Air transport
# 14              356262            43626              0
# 15              422930            47129            255
# 16              474743            25033           9711
# 17              507668             4502          26223
# 18              579295             5023          29260
# 19      Road transport  Water transport  Air transport
# 20              840472             4895           3079
# 21             1069740             2559           5848
# 22             1347912             1728           4557
# 23             1572288             2228          13599
# 24             1833696             2228          13599
# 25      Road transport  Water transport  Air transport
# 26              275736                0           2217
# 27              320533                0           4215
# 28              357128                0           3337
# 29              386628                0           9507
# ..                 ...              ...            ...
# 132            2866546            66379          43317
# 133            3309408            62574          80632
# 134            3581990            59573          62921
# 135            3660994            70414         180836
# 136            3851117            83962         339750
# 137            3978671           100526         492323
# 138     Road transport  Water transport  Air transport
# 139            1461278                0          23258
# 140            1715757                0          43171
# 141            1869092                0          34506
# 142            2055658                0         120691
# 143            2418848                0         158647
# 144            2863507                0         217072
# 145     Road transport  Water transport  Air transport
# 146                NaN              NaN            NaN
# 147                NaN              NaN            NaN
# 148                NaN              NaN            NaN
# 149                NaN              NaN            NaN
# 150     Road transport  Water transport  Air transport
# 151            1976901             1496           7630
# 152            2477770              783          14732
# 153            2885934              528          15692
# 154            3645747              681          36582
# 155            4269516              798          42841
# 156    Road transport*  Water transport  Air transport
# 157             218487              NaN            652
# 158             259840              NaN           1229
# 159             287156              NaN           2158
# 160             307147              NaN           3889
# 161             339240              NaN           7053
#
# S.No.                                7.5      7.6  \
# 0       Services incidental to transport  Storage
# 1                                 501800    20700
# 2                                 535500    16600
# 3                                 634700    18700
# 4                                 780200    18700
# 5                                 904200    19000
# 6                                1020800    20600
# 7       Services incidental to transport  Storage
# 8                                     78        0
# 9                                     89        0
# 10                                   100        0
# 11                                   109        0
# 12                                   121        0
# 13      Services incidental to transport  Storage
# 14                                 36400     6594
# 15                                 39855     7277
# 16                                 36798     8377
# 17                                 35739    10308
# 18                                 37732    12070
# 19      Services incidental to transport  Storage
# 20                                 89270     7400
# 21                                112022     8434
# 22                                142482     8457
# 23                                166600    10618
# 24                                194712    10618
# 25      Services incidental to transport  Storage
# 26                                  3756    10189
# 27                                  4347    11689
# 28                                  4818    14026
# 29                                  5232    16675
# ..                                   ...      ...
# 132                               822307    26961
# 133                               951481    28773
# 134                               939475    33162
# 135                               864407    39834
# 136                               980474    48814
# 137                              1113679    60273
# 138     Services incidental to transport  Storage
# 139                               371763    17531
# 140                               484436    15328
# 141                               447736    17085
# 142                               454909    19805
# 143                               513777    24206
# 144                               593688    28510
# 145    Services incidental to transport*  Storage
# 146                                46677      151
# 147                                63696      187
# 148                                65236      205
# 149                                88721      254
# 150     Services incidental to transport  Storage
# 151                                 9842   111006
# 152                                12019   122608
# 153                                14738   137454
# 154                                16323   171696
# 155                                19116   196868
# 156     Services incidental to transport  Storage
# 157                                  NaN      579
# 158                                  NaN      678
# 159                                  NaN      735
# 160                                  -76      660
# 161                                  NaN      699
#
# S.No.                                               7.7                   8  \
# 0      Communication & services related to broadcasting  Financial services
# 1                                                540200             1425608
# 2                                                621430             1584297
# 3                                                796043             1710463
# 4                                                928756             1900863
# 5                                               1093530             2125508
# 6                                               1329645             2415390
# 7      Communication & services related to broadcasting  Financial services
# 8                                                 10930               20884
# 9                                                 13565               21562
# 10                                                17208               23571
# 11                                                19568               25207
# 12                                                22234               27548
# 13     Communication & services related to broadcasting  Financial services
# 14                                               208875              427077
# 15                                               225434              457213
# 16                                               316833              515905
# 17                                               357619              543651
# 18                                               434772              591575
# 19     Communication & services related to broadcasting  Financial services
# 20                                               534222              883932
# 21                                               628197              977417
# 22                                               784175             1122273
# 23                                               919427             1178022
# 24                                              1062941             1236540
# 25     Communication & services related to broadcasting  Financial services
# 26                                               170301              537699
# 27                                               202117              609344
# 28                                               253906              676094
# 29                                               294552              739057
# ..                                                  ...                 ...
# 132                                             1196369             4019599
# 133                                             1342653             4466210
# 134                                             1647489             5088062
# 135                                             1903283             5598498
# 136                                             2156406             5990393
# 137                                             2453571             6849037
# 138    Communication & services related to broadcasting  Financial services
# 139                                              496542             2126507
# 140                                              552707             2363216
# 141                                              668344             2659553
# 142                                              753992             3023729
# 143                                              860584             3312302
# 144                                              983752             3700835
# 145    Communication & services related to broadcasting  Financial services
# 146                                               37264               57103
# 147                                               44751               67963
# 148                                               55563               72348
# 149                                               66676               86094
# 150    Communication & services related to broadcasting  Financial services
# 151                                              875159             2518230
# 152                                             1064051             2862582
# 153                                             1649436             3133376
# 154                                             1914737             3392275
# 155                                             2016218             3605988
# 156    Communication & services related to broadcasting  Financial services
# 157                                              469848              293318
# 158                                              547386              320421
# 159                                              644389              357514
# 160                                              733778              385030
# 161                                              852770              421624
#
# S.No.                                                  9  \
# 0      Real estate, ownership of dwelling & professio...
# 1                                                2833805
# 2                                                3434098
# 3                                                3897345
# 4                                                4405409
# 5                                                5092310
# 6                                                5942431
# 7      Real estate, ownership of dwelling & professio...
# 8                                                  38261
# 9                                                  41869
# 10                                                 44949
# 11                                                 48418
# 12                                                 50432
# 13     Real estate, ownership of dwelling & professio...
# 14                                               1112543
# 15                                               1225917
# 16                                               1316472
# 17                                               1412466
# 18                                               1534435
# 19     Real estate, ownership of dwelling & professio...
# 20                                               2802336
# 21                                               3121656
# 22                                               3460385
# 23                                               3740641
# 24                                               4081952
# 25     Real estate, ownership of dwelling & professio...
# 26                                               1755211
# 27                                               1919629
# 28                                               2227586
# 29                                               2462166
# ..                                                   ...
# 132                                             10253371
# 133                                             12096018
# 134                                             14291455
# 135                                             16830213
# 136                                             19831868
# 137                                             23022995
# 138    Real estate, ownership of dwelling & professio...
# 139                                              5551356
# 140                                              6924491
# 141                                              8230664
# 142                                              9478839
# 143                                             10903589
# 144                                             12506017
# 145    Real estate, ownership of dwelling & professio...
# 146                                               119572
# 147                                               135500
# 148                                               168765
# 149                                               190704
# 150    Real estate, ownership of dwelling & professio...
# 151                                              9745417
# 152                                             11527819
# 153                                             13018473
# 154                                             14548185
# 155                                             16038848
# 156    Real estate, ownership of dwelling & professio...
# 157                                               588825
# 158                                               671182
# 159                                               739177
# 160                                               831307
# 161                                               935310
#
# S.No.                     10              11        Total  \
# 0      Public administration  Other services     Tertiary
# 1                    1393752         2730376     14308520
# 2                    1552379         3063920     16592526
# 3                    1738971         3538298     19035788
# 4                    2200897         4215389     22032942
# 5                    2594904         5248604     25445252
# 6                    3039676         6180240     29518654
# 7      Public administration  Other services     Tertiary
# 8                     135418          142509       420384
# 9                     149466          167431       458512
# 10                    183105          189928       545461
# 11                    243867          218728       631844
# 12                    265622          257504       709785
# 13     Public administration  Other services     Tertiary
# 14                    821723         1077923      6295033
# 15                    929477         1182533      7008377
# 16                    982734         1493924      7969726
# 17                   1373611         1795658      9307109
# 18                   1556575         2209442     10765482
# 19     Public administration  Other services     Tertiary
# 20                   1358743         2219262     13409194
# 21                   1477676         2804281     15718193
# 22                   1576835         3404578     17454166
# 23                   2078171         4587589     22179969
# 24                   2129474         4845291     24740642
# 25     Public administration  Other services     Tertiary
# 26                    549383          781803      5140421
# 27                    611344          875123      5800031
# 28                    781483          914758      6672218
# 29                    867982         1112232      7588778
# ..                       ...             ...          ...
# 132                  2598408         4842953     34982454
# 133                  2572501         5483888     40456183
# 134                  2962600         6378431     46791906
# 135                  3400800         7430115     53343788
# 136                  3728920         8569379     60697126
# 137                  4561182         9858347     68444352
# 138    Public administration  Other services     Tertiary
# 139                  1131292         2670927     17759630
# 140                  1265964         3035381     21030740
# 141                  1433832         3546015     24227333
# 142                  1711265         4158229     28471410
# 143                  2061873         4848041     32789342
# 144                  2244545         5442671     37576197
# 145    Public administration  Other services     Tertiary
# 146                   241678          255446       984954
# 147                   270564          260210  1.10842e+06
# 148                   302004          316948  1.31502e+06
# 149                   338244          323287  1.48471e+06
# 150    Public administration  Other services     Tertiary
# 151                  4234830         3540115     31033323
# 152                  5058674         3862890     35704339
# 153                  5483464         4318007     40768646
# 154                  6152124         5034623     45968959
# 155                  6823321         5623362     50774526
# 156    Public administration  Other services     Tertiary
# 157                   412001          498856   3.6896e+06
# 158                   323723          668947  4.21879e+06
# 159                   483887          827478  4.97428e+06
# 160                   579409          982430  5.58798e+06
# 161                   711920     1.25526e+06  6.53995e+06
#
# S.No.                          12                 13                     14  \
# 0      TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 1                        34975303            4243900                1279000
# 2                        37947671            4656500                1463800
# 3                        42672154            5263500                1508500
# 4                        48825542            5512100                1690800
# 5                        55721862            6719300                1447800
# 6                        64169719            7236500                1475500
# 7      TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 8                         1085471              41341                  20542
# 9                         1240356              43899                  29591
# 10                        1426923              62683                  29405
# 11                        1636292              70099                  30272
# 12                        1831214              78392                  31165
# 13     TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 14                       13529020            1203476                 415005
# 15                       14860974            1346785                 521335
# 16                       16785025            1519305                 529808
# 17                       18666897            1725309                 582406
# 18                       21123673            1945496                 645770
# 19     TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 20                       24169849            1716948                1172402
# 21                       27669913            2118544                1551663
# 22                       30668542            2623561                1581969
# 23                       36184863            3213546                2006421
# 24                       39827966            4067111                2544756
# 25     TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 26                       14842983            1704500                 740100
# 27                       16613332            2087500                 949700
# 28                       19528409            2193874                1053267
# 29                       22228481            2601791                1332092
# ..                            ...                ...                    ...
# 132                      69302145            8455881                2609517
# 133                      78542719           10014105                3008738
# 134                      88837364           10988371                2716748
# 135                      99515453           12507325                2766405
# 136                     109714667           14407032                2854900
# 137                     120325477           16216539                2665416
# 138    TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 139                      33604865            3281100                 942700
# 140                      37516212            3716400                1083300
# 141                      42233460            4092900                1107800
# 142                      47528765            4425700                 836700
# 143                      52638049            6034600                1109500
# 144                      60066578            6382500                1019700
# 145    TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 146                   1.87955e+06             103607                  62319
# 147                   2.12894e+06             118636                  81254
# 148                   2.50394e+06             149345                  94002
# 149                   2.91132e+06             149345                  94002
# 150    TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 151                      68189274            7063424                2847843
# 152                      77771564            7797300                3278565
# 153                      88540856            8962314                3088598
# 154                      97516938           10107396                3287219
# 155                     107753705           11008735                3382981
# 156    TOTAL GSVA at basic prices  Taxes on Products  Subsidies on products
# 157                   1.08529e+07             919682                 220207
# 158                   1.23971e+07        1.06737e+06                 280963
# 159                   1.39656e+07        1.27405e+06                 257991
# 160                   1.50768e+07        1.43486e+06                 313139
# 161                     1.706e+07        1.70482e+06                 355716
#
# S.No.                            15                16                     17  \
# 0      Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 1                          37940203            492750                  76997
# 2                          41140371            495660                  83001
# 3                          46427154            498570                  93121
# 4                          52646842            501510                 104977
# 5                          60993362            504460                 120908
# 6                          69930719            507430                 137814
# 7      Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 8                           1106270             14000                  79019
# 9                           1254664             14280                  87862
# 10                          1460201             14570                 100220
# 11                          1676119             14870                 112718
# 12                          1878441             15160                 123908
# 13     Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 14                         14317491            314410                  45538
# 15                         15686424            318480                  49254
# 16                         17774522            322600                  55098
# 17                         19809800            326780                  60621
# 18                         22423399            331010                  67742
# 19     Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 20                         24714396           1050570                  23525
# 21                         28236794           1067200                  26459
# 22                         31710134           1084080                  29251
# 23                         37391988           1101240                  33954
# 24                         41350321           1118670                  36964
# 25     Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 26                         15807383            257850                  61305
# 27                         17751132            262010                  67750
# 28                         20669016            266240                  77633
# 29                         23498180            270530                  86860
# ..                              ...               ...                    ...
# 132                        75148509            725370                 103600
# 133                        85548086            732110                 116851
# 134                        97108987            738900                 131424
# 135                       109256373            745760                 146503
# 136                       121266799            752690                 161111
# 137                       133876600            759680                 176228
# 138    Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 139                        35943265            356820                 100732
# 140                        40149312            360400                 111402
# 141                        45218560            364010                 124223
# 142                        51117765            367660                 139035
# 143                        57563149            371340                 155015
# 144                        65429378            375050                 174455
# 145    Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 146                     1.92084e+06             37000                  51915
# 147                     2.16632e+06             37440                  57861
# 148                     2.55928e+06             37890                  67545
# 149                     2.96666e+06             38350                  77358
# 150    Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 151                        72404855           2015910                  35917
# 152                        82290299           2046780                  40205
# 153                        94414572           2078120                  45433
# 154                       104337115           2109940                  49450
# 155                       115379459           2110940                  54658
# 156    Gross State Domestic Product  Population ('00)  Per Capita GSDP (Rs.)
# 157                     1.15523e+07            101650                 113648
# 158                     1.31835e+07            103020                 127971
# 159                     1.49817e+07            104410                 143489
# 160                     1.61985e+07            105820                 153076
# 161                     1.84091e+07            107240                 171663
#
# S.No.              State
# 0         Andhra Pradesh
# 1         Andhra Pradesh
# 2         Andhra Pradesh
# 3         Andhra Pradesh
# 4         Andhra Pradesh
# 5         Andhra Pradesh
# 6         Andhra Pradesh
# 7      Arunachal Pradesh
# 8      Arunachal Pradesh
# 9      Arunachal Pradesh
# 10     Arunachal Pradesh
# 11     Arunachal Pradesh
# 12     Arunachal Pradesh
# 13                 Assam
# 14                 Assam
# 15                 Assam
# 16                 Assam
# 17                 Assam
# 18                 Assam
# 19                 Bihar
# 20                 Bihar
# 21                 Bihar
# 22                 Bihar
# 23                 Bihar
# 24                 Bihar
# 25           Chattisgarh
# 26           Chattisgarh
# 27           Chattisgarh
# 28           Chattisgarh
# 29           Chattisgarh
# ..                   ...
# 132           Tamil Nadu
# 133           Tamil Nadu
# 134           Tamil Nadu
# 135           Tamil Nadu
# 136           Tamil Nadu
# 137           Tamil Nadu
# 138            Telangana
# 139            Telangana
# 140            Telangana
# 141            Telangana
# 142            Telangana
# 143            Telangana
# 144            Telangana
# 145              Tripura
# 146              Tripura
# 147              Tripura
# 148              Tripura
# 149              Tripura
# 150        Uttar Pradesh
# 151        Uttar Pradesh
# 152        Uttar Pradesh
# 153        Uttar Pradesh
# 154        Uttar Pradesh
# 155        Uttar Pradesh
# 156          Uttarakhand
# 157          Uttarakhand
# 158          Uttarakhand
# 159          Uttarakhand
# 160          Uttarakhand
# 161          Uttarakhand
#
# [162 rows x 34 columns]

# %% [markdown]
# As the States GSDP data is required at a later point, we shall deal with the above dataset at a later point.
#
# Let's now point our focus to load and clean th data for <b>Part I-A</b>

# %%
# Importing the files via loadCSV() user-defined function. The files is loaded from the "Data" folder present.
def loadCSV(csvName):
    nameOfVariable = pd.read_csv("./Data/" + csvName, encoding = 'unicode_escape')
    return nameOfVariable

# Pulling Data 1A
csvName = "Data1A/Data1-GSDPdata.csv"
dfGSDP = loadCSV(csvName)

# Pulling data required for Data 2
csvName = "Data2/Data2.csv"
data2 = loadCSV(csvName)

# %% [markdown]
# # Part I - GDP Analysis of the Indian States

# %%
# Making a temp variable for this snippet of code to analyze GSDP
df = dfGSDP
df.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  Himachal Pradesh  Jammu & Kashmir  Jharkhand  Karnataka  \
# 0  297539.0           72720.0          78254.0   150918.0   603778.0
# 1  347032.0           82820.0          87105.0   174724.0   691700.0
# 2  400662.0           94764.0          95893.0   188567.0   817886.0
# 3  437462.0          104369.0         100404.0   217107.0   921788.0
# 4  485184.0               NaN         118387.0   241955.0  1027068.0
#
#      Kerala  Madhya Pradesh  Maharashtra  Manipur  Meghalaya  Mizoram  \
# 0  364048.0        315561.0    1272967.0  12915.0    19918.0   7259.0
# 1  412313.0        380924.0    1448466.0  13748.0    21872.0   8362.0
# 2  465041.0        437737.0    1647506.0  16198.0    22938.0  10293.0
# 3  526002.0        481982.0    1792122.0  18043.0    24408.0  11559.0
# 4  588337.0        543975.0          NaN      NaN    26745.0      NaN
#
#    Nagaland    Odisha    Punjab  Rajasthan   Sikkim  Tamil Nadu  Telangana  \
# 0   11839.0  227872.0  266628.0   436465.0  11165.0    751485.0   359433.0
# 1   13619.0  258275.0  297734.0   494004.0  12338.0    855481.0   401493.0
# 2   16612.0  291709.0  334714.0   549701.0  13862.0    971090.0   452186.0
# 3   18414.0  321971.0  368011.0   612194.0  15209.0   1092564.0   511178.0
# 4       NaN  341887.0       NaN        NaN  16637.0   1212668.0   575631.0
#
#    Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 0  19208.0       724049.0     115523.0           NaN
# 1  21663.0       822903.0     131835.0           NaN
# 2  25593.0       944146.0     149817.0           NaN
# 3  29667.0      1043371.0     161985.0           NaN
# 4      NaN      1153795.0     184091.0           NaN
#
#    Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  All_India GDP
# 0                     3979.0     18768.0  343767.0     16818.0      8736039.0
# 1                     4421.0     21609.0  391238.0     18875.0      9946636.0
# 2                     5159.0     24787.0  443783.0     21870.0     11236635.0
# 3                     5721.0     27844.0  492424.0     24089.0     12433749.0
# 4                        NaN     30304.0  551963.0     26533.0     13675331.0

# %%
df.shape
# Out:
# (11, 36)

# %%
# Having a look at the columns of the dataset
df.columns
# Out:
# Index(['Items  Description', 'Duration', 'Andhra Pradesh ',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands',
#        'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP'],
#       dtype='object')

# %%
# Making sure that the inferred data has the expected schema
df.dtypes
# Out:
# Items  Description            object
# Duration                      object
# Andhra Pradesh               float64
# Arunachal Pradesh            float64
# Assam                        float64
# Bihar                        float64
# Chhattisgarh                 float64
# Goa                          float64
# Gujarat                      float64
# Haryana                      float64
# Himachal Pradesh             float64
# Jammu & Kashmir              float64
# Jharkhand                    float64
# Karnataka                    float64
# Kerala                       float64
# Madhya Pradesh               float64
# Maharashtra                  float64
# Manipur                      float64
# Meghalaya                    float64
# Mizoram                      float64
# Nagaland                     float64
# Odisha                       float64
# Punjab                       float64
# Rajasthan                    float64
# Sikkim                       float64
# Tamil Nadu                   float64
# Telangana                    float64
# Tripura                      float64
# Uttar Pradesh                float64
# Uttarakhand                  float64
# West Bengal1                 float64
# Andaman & Nicobar Islands    float64
# Chandigarh                   float64
# Delhi                        float64
# Puducherry                   float64
# All_India GDP                float64
# dtype: object

# %%
# Looking at the total number of null values present in the dataset
df.isnull().sum().sum()
# Out:
# 73

# %%
# Looking at NaN values at a column level to understand NaN trends
df.isnull().sum()
# Out:
# Items  Description            0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# Uttarakhand                   2
# West Bengal1                 11
# Andaman & Nicobar Islands     4
# Chandigarh                    2
# Delhi                         0
# Puducherry                    0
# All_India GDP                 0
# dtype: int64

# %% [markdown]
# Here, we notice that <b>West Bengal</b> has not been up to the mark in providing the government with GDP data, with <b>all</b> of the values in the column missing, we shall not proceed to remove the columns that houses West bengal

# %%
# Dropping West Bengal from the dataframe and performing a quick sense check of the data
df = df.drop('West Bengal1' , axis='columns')
df.shape
# Out:
# (11, 35)

# %% [markdown]
# The datset now has 11 rows and 35 columns

# %%
# Code to understand the pattern of missing values row-wise
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      9
# 5     22
# 6      0
# 7      0
# 8      0
# 9      9
# 10    22
# dtype: int64

# %% [markdown]
# We notice that the data for 2016-17, whose absolute value (in crores) and growth % - (rows 6 and 11 respctively) have over 61% of missing value as data may not have been collected accurately as the report was being made. So, we shall be removing the rows for the purposes of data cleaning.
#
# Further, we also notice that the data for the time-period for of 2015-16 has 9 missing values, we have decided to keep the rows for analytical purposes.

# %%
# Code to keep rows where at least 50% of the data is present
df = df.dropna(thresh=18)
df.isnull().sum(axis=1)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    9
# 6    0
# 7    0
# 8    0
# 9    9
# dtype: int64

# %%
# Post cleaning and handling NA values, we now proceed to display the data 
# Perform a sense check and re-assess the level of the data
df.head()
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  Himachal Pradesh  Jammu & Kashmir  Jharkhand  Karnataka  \
# 0  297539.0           72720.0          78254.0   150918.0   603778.0
# 1  347032.0           82820.0          87105.0   174724.0   691700.0
# 2  400662.0           94764.0          95893.0   188567.0   817886.0
# 3  437462.0          104369.0         100404.0   217107.0   921788.0
# 4  485184.0               NaN         118387.0   241955.0  1027068.0
#
#      Kerala  Madhya Pradesh  Maharashtra  Manipur  Meghalaya  Mizoram  \
# 0  364048.0        315561.0    1272967.0  12915.0    19918.0   7259.0
# 1  412313.0        380924.0    1448466.0  13748.0    21872.0   8362.0
# 2  465041.0        437737.0    1647506.0  16198.0    22938.0  10293.0
# 3  526002.0        481982.0    1792122.0  18043.0    24408.0  11559.0
# 4  588337.0        543975.0          NaN      NaN    26745.0      NaN
#
#    Nagaland    Odisha    Punjab  Rajasthan   Sikkim  Tamil Nadu  Telangana  \
# 0   11839.0  227872.0  266628.0   436465.0  11165.0    751485.0   359433.0
# 1   13619.0  258275.0  297734.0   494004.0  12338.0    855481.0   401493.0
# 2   16612.0  291709.0  334714.0   549701.0  13862.0    971090.0   452186.0
# 3   18414.0  321971.0  368011.0   612194.0  15209.0   1092564.0   511178.0
# 4       NaN  341887.0       NaN        NaN  16637.0   1212668.0   575631.0
#
#    Tripura  Uttar Pradesh  Uttarakhand  Andaman & Nicobar Islands  Chandigarh  \
# 0  19208.0       724049.0     115523.0                     3979.0     18768.0
# 1  21663.0       822903.0     131835.0                     4421.0     21609.0
# 2  25593.0       944146.0     149817.0                     5159.0     24787.0
# 3  29667.0      1043371.0     161985.0                     5721.0     27844.0
# 4      NaN      1153795.0     184091.0                        NaN     30304.0
#
#       Delhi  Puducherry  All_India GDP
# 0  343767.0     16818.0      8736039.0
# 1  391238.0     18875.0      9946636.0
# 2  443783.0     21870.0     11236635.0
# 3  492424.0     24089.0     12433749.0
# 4  551963.0     26533.0     13675331.0

# %% [markdown]
# Here, we notice that the first 5 and last 4 rows have the same name, so the level of the data is at a
#
# "Items Description"-"Duration" level". We shall use the 'Duation' column as the unique identifier.

# %%
# Renaming the columns to make the naming nomenclature more intuitive
df.rename(columns={'Items  Description':'GDPType_Duration', 'All_India GDP':'All_India_GDP'}, inplace=True)

# %% [markdown]
# On observing the dataframe at hand, we realize that the scale of the dataframe across rows is not the same across rows.
# We have two sets in the rows
# 1. GSDP Current Prices
# 2. % Growth over previous year
#
# We shall be slicing the data to get 2 subsets of dfCurrentPrices that consists of the GSDP CURRENT PRICES (In Crores) and dfPercentageGrowth that gives us the % growth over previous year.

# %%
# Slicing the data to get the Current Price and % Growth as separate dataframes to carry out analysis
dfCurrentPrices = df.iloc[0:5,:]
dfPercentageGrowth = df.iloc[5:10,:]

# %%
# Reindexing the data
dfCurrentPrices.reset_index(inplace = True, drop = True)
dfPercentageGrowth.reset_index(inplace = True, drop = True)

# %%
# Sense check of data
dfCurrentPrices
# Out:
#                      GDPType_Duration Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12         379402.0
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13         411404.0
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14         464272.0
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15         526468.0
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            11063.0  143175.0  247144.0      158074.0  42367.0  615606.0
# 1            12547.0  156864.0  282368.0      177511.0  38120.0  724495.0
# 2            14602.0  177745.0  317101.0      206690.0  35921.0  807623.0
# 3            16761.0  198098.0  373920.0      234982.0  40633.0  895027.0
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  Himachal Pradesh  Jammu & Kashmir  Jharkhand  Karnataka  \
# 0  297539.0           72720.0          78254.0   150918.0   603778.0
# 1  347032.0           82820.0          87105.0   174724.0   691700.0
# 2  400662.0           94764.0          95893.0   188567.0   817886.0
# 3  437462.0          104369.0         100404.0   217107.0   921788.0
# 4  485184.0               NaN         118387.0   241955.0  1027068.0
#
#      Kerala  Madhya Pradesh  Maharashtra  Manipur  Meghalaya  Mizoram  \
# 0  364048.0        315561.0    1272967.0  12915.0    19918.0   7259.0
# 1  412313.0        380924.0    1448466.0  13748.0    21872.0   8362.0
# 2  465041.0        437737.0    1647506.0  16198.0    22938.0  10293.0
# 3  526002.0        481982.0    1792122.0  18043.0    24408.0  11559.0
# 4  588337.0        543975.0          NaN      NaN    26745.0      NaN
#
#    Nagaland    Odisha    Punjab  Rajasthan   Sikkim  Tamil Nadu  Telangana  \
# 0   11839.0  227872.0  266628.0   436465.0  11165.0    751485.0   359433.0
# 1   13619.0  258275.0  297734.0   494004.0  12338.0    855481.0   401493.0
# 2   16612.0  291709.0  334714.0   549701.0  13862.0    971090.0   452186.0
# 3   18414.0  321971.0  368011.0   612194.0  15209.0   1092564.0   511178.0
# 4       NaN  341887.0       NaN        NaN  16637.0   1212668.0   575631.0
#
#    Tripura  Uttar Pradesh  Uttarakhand  Andaman & Nicobar Islands  Chandigarh  \
# 0  19208.0       724049.0     115523.0                     3979.0     18768.0
# 1  21663.0       822903.0     131835.0                     4421.0     21609.0
# 2  25593.0       944146.0     149817.0                     5159.0     24787.0
# 3  29667.0      1043371.0     161985.0                     5721.0     27844.0
# 4      NaN      1153795.0     184091.0                        NaN     30304.0
#
#       Delhi  Puducherry  All_India_GDP
# 0  343767.0     16818.0      8736039.0
# 1  391238.0     18875.0      9946636.0
# 2  443783.0     21870.0     11236635.0
# 3  492424.0     24089.0     12433749.0
# 4  551963.0     26533.0     13675331.0

# %%
# Sense check of data
dfPercentageGrowth
# Out:
#                 GDPType_Duration Duration  Andhra Pradesh   Arunachal Pradesh  \
# 0  (% Growth over previous year)  2012-13             8.43              13.41
# 1  (% Growth over previous year)  2013-14            12.85              16.38
# 2  (% Growth over previous year)  2014-15            13.40              14.79
# 3  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  Himachal Pradesh  \
# 0   9.56  14.25         12.30 -10.02    17.69    16.63             13.89
# 1  13.31  12.30         16.44  -5.77    11.47    15.45             14.42
# 2  11.45  17.92         13.69  13.12    10.82     9.18             10.14
# 3  13.19  10.59         10.98  10.75    11.09    10.91               NaN
#
#    Jammu & Kashmir  Jharkhand  Karnataka  Kerala  Madhya Pradesh  Maharashtra  \
# 0            11.31      15.77      14.56   13.26           20.71        13.79
# 1            10.09       7.92      18.24   12.79           14.91        13.74
# 2             4.70      15.14      12.70   13.11           10.11         8.78
# 3            17.91      11.44      11.42   11.85           12.86          NaN
#
#    Manipur  Meghalaya  Mizoram  Nagaland  Odisha  Punjab  Rajasthan  Sikkim  \
# 0     6.45       9.81     15.2     15.03   13.34   11.67      13.18   10.51
# 1    17.83       4.87     23.1     21.98   12.95   12.42      11.27   12.35
# 2    11.39       6.41     12.3     10.85   10.37    9.95      11.37    9.72
# 3      NaN       9.58      NaN       NaN    6.19     NaN        NaN    9.39
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0       13.84      11.70    12.78          13.65        14.12
# 1       13.51      12.63    18.14          14.73        13.64
# 2       12.51      13.05    15.92          10.51         8.12
# 3       10.99      12.61      NaN          10.58        13.65
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India_GDP
# 0                      11.13       15.14  13.81       12.23          13.86
# 1                      16.68       14.71  13.43       15.87          12.97
# 2                      10.89       12.33  10.96       10.14          10.65
# 3                        NaN        8.84  12.09       10.15           9.99

# %% [markdown]
# The All India GDP heavily skews the data and makes graphs difficult to look at! So, we shall perform analysis on the <b>All India GDP</b> separately and plot grahs for the same separately and then proceed to do analysis on the rest of the columns.

# %% [markdown]
# ### Part I: GDP Analysis of the State
# <i> Note: </i>Plots made should preferably be in ascending/ descending order for easy interpretation
#
# The steps for the analysis of Part 1-A will include the below steps (in no particular order):
# - Loading the csvs from a set folder that consists of all the necessary data
# - Performing sense checks on data to ensure that there are no corrupt files
# - Analysis of missing values
# - Treatment of missing values
# - Graph (in ascending/ descending order) showing "% Growth over previous year" for <b>All States</b> using line graphs. Use best fit line to represent growth for each state
# - Similar graph representing the growth of the nation as well

# %% [markdown]
# ### All India GDP

# %%
# Subsetting all India GDP Prices in the variable dfCurrentPricesAllIndiaGDP
dfCurrentPricesAllIndiaGDP = dfCurrentPrices.iloc[:,[1,-1]]
dfCurrentPricesAllIndiaGDP
# Out:
#   Duration  All_India_GDP
# 0  2011-12      8736039.0
# 1  2012-13      9946636.0
# 2  2013-14     11236635.0
# 3  2014-15     12433749.0
# 4  2015-16     13675331.0

# %% [markdown]
# #### GSDP - Current Prices (All India GDP)

# %%
# Sorting and resetting the index to ensure that the plots displayed are in order
dfCurrentPricesAllIndiaGDP = dfCurrentPricesAllIndiaGDP.sort_values(['All_India_GDP']).reset_index(inplace = True, drop = True)

# Assigning All India GDP values to the variable 'y' and (GDP Type and Duration) to variable 'x'
x = dfCurrentPrices.Duration
y = dfCurrentPrices.All_India_GDP

# Plotting both bar plot and best fit line in the same plot
sns.set(style="white", rc={"lines.linewidth": 3})

fig, ax1 = plt.subplots(figsize=(5,5))
ax2 = ax1.twinx()
sns.barplot(x, y, color='#004488', ax=ax1)
sns.lineplot(x, y, color='r', marker="o", ax=ax2)
plt.show()
sns.set()

# %% [markdown]
# #### GSDP - % Growth (All India GDP)

# %%
# Subsetting all India % Growth in the variable dfPercentageGrowthAllIndiaGDP
dfPercentageGrowthAllIndiaGDP = dfPercentageGrowth.iloc[:, [1,-1]]
dfPercentageGrowthAllIndiaGDP

dfPercentageGrowthAllIndiaGDP.rename(columns={'All_India_GDP':'All_India_GDP_Percentage_Growth'}, inplace=True)
# Out:
# E:\Miniconda\envs\ipykernel\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
# Sorting the GDP % Growth values to ensure optimal graphs for All India GDP
dfPercentageGrowthAllIndiaGDP = dfPercentageGrowthAllIndiaGDP.sort_values(['All_India_GDP_Percentage_Growth']).reset_index(drop = True)

# Assigning All India GDP values to the variable 'y' and (GDP Type and Duration) to variable 'x'
x = dfPercentageGrowthAllIndiaGDP.Duration
y = dfPercentageGrowthAllIndiaGDP.All_India_GDP_Percentage_Growth

# Plotting both bar plot and best fit line in the same plot
sns.set(style="white", rc={"lines.linewidth": 3})

fig, ax1 = plt.subplots(figsize=(5,5))
ax2 = ax1.twinx()

# Bar plot
sns.barplot(x, y, color='#004488', ax=ax1)

#Line Plot 
sns.lineplot(x, y, color='r', marker="o", ax=ax2)
plt.show()
sns.set()

# %%
# Sense check of sliced % growth data
dfPercentageGrowth
# Out:
#                 GDPType_Duration Duration  Andhra Pradesh   Arunachal Pradesh  \
# 0  (% Growth over previous year)  2012-13             8.43              13.41
# 1  (% Growth over previous year)  2013-14            12.85              16.38
# 2  (% Growth over previous year)  2014-15            13.40              14.79
# 3  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  Himachal Pradesh  \
# 0   9.56  14.25         12.30 -10.02    17.69    16.63             13.89
# 1  13.31  12.30         16.44  -5.77    11.47    15.45             14.42
# 2  11.45  17.92         13.69  13.12    10.82     9.18             10.14
# 3  13.19  10.59         10.98  10.75    11.09    10.91               NaN
#
#    Jammu & Kashmir  Jharkhand  Karnataka  Kerala  Madhya Pradesh  Maharashtra  \
# 0            11.31      15.77      14.56   13.26           20.71        13.79
# 1            10.09       7.92      18.24   12.79           14.91        13.74
# 2             4.70      15.14      12.70   13.11           10.11         8.78
# 3            17.91      11.44      11.42   11.85           12.86          NaN
#
#    Manipur  Meghalaya  Mizoram  Nagaland  Odisha  Punjab  Rajasthan  Sikkim  \
# 0     6.45       9.81     15.2     15.03   13.34   11.67      13.18   10.51
# 1    17.83       4.87     23.1     21.98   12.95   12.42      11.27   12.35
# 2    11.39       6.41     12.3     10.85   10.37    9.95      11.37    9.72
# 3      NaN       9.58      NaN       NaN    6.19     NaN        NaN    9.39
#
#    Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 0       13.84      11.70    12.78          13.65        14.12
# 1       13.51      12.63    18.14          14.73        13.64
# 2       12.51      13.05    15.92          10.51         8.12
# 3       10.99      12.61      NaN          10.58        13.65
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India_GDP
# 0                      11.13       15.14  13.81       12.23          13.86
# 1                      16.68       14.71  13.43       15.87          12.97
# 2                      10.89       12.33  10.96       10.14          10.65
# 3                        NaN        8.84  12.09       10.15           9.99

# %%
# Removing All_India_GDP from the dfCurrentProcess dataset to focus on the States
dfCurrentPrices = dfCurrentPrices.iloc[0:5, 1:34]
dfPercentageGrowth = dfPercentageGrowth.iloc[0:4, 1:34]

# %% [markdown]
# For the purposes of plotting, it is always preferred that one uses data in <b>tall-format</b>, rather than wide. So, we shall be transposing the sliced datasets of Current Prices and % growth.

# %%
# Transposing the dfCurrentPrices dataset 
tdfCurrentPrices = dfCurrentPrices.transpose()

# When transposing, the first column of the inital dataframe becomes the first row of the transposed dataframe
# Code to move the first rows of dataframe as column headers and drop first row
tdfCurrentPrices.columns = tdfCurrentPrices.iloc[0]
tdfCurrentPrices = tdfCurrentPrices.drop(tdfCurrentPrices.index[0])

# Typecasting the data from string (object) to type int
tdfCurrentPrices = tdfCurrentPrices.astype(str).astype(float)
tdfCurrentPrices['Average_Growth_Current_Price'] = tdfCurrentPrices.mean(axis = 1)

# Making the index a new column and re-indexing th pandas dataframe
tdfCurrentPrices['States'] = tdfCurrentPrices.index
tdfCurrentPrices.reset_index(inplace = True, drop = True)

# Printing the dataset for sense check
tdfCurrentPrices.head()
# Out:
# Duration   2011-12   2012-13   2013-14   2014-15   2015-16  \
# 0         379402.0  411404.0  464272.0  526468.0  609934.0
# 1          11063.0   12547.0   14602.0   16761.0   18784.0
# 2         143175.0  156864.0  177745.0  198098.0  224234.0
# 3         247144.0  282368.0  317101.0  373920.0  413503.0
# 4         158074.0  177511.0  206690.0  234982.0  260776.0
#
# Duration  Average_Growth_Current_Price             States
# 0                             478296.0    Andhra Pradesh
# 1                              14751.4  Arunachal Pradesh
# 2                             180023.2              Assam
# 3                             326807.2              Bihar
# 4                             207606.6       Chhattisgarh

# %% [markdown]
# #### State-wise absolute Current Prices (GDP Analysis)

# %%
# Sorting absolute Current Prices values
tdfCurrentPrices = tdfCurrentPrices.sort_values(['Average_Growth_Current_Price']).reset_index(drop = True)

# Specifying the values of x-axis and y-axis
x = tdfCurrentPrices.States
y = tdfCurrentPrices.Average_Growth_Current_Price
sns.set(style="white")

# Deciding the size of the graph to be plotted 
fig, ax = plt.subplots(figsize=(30,10))

# Plotting a bar plot
ax1 = sns.barplot(x, y, color='#004488')

# Rotating the State names by 45 degrees
ax1.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()

# Displaying the plot along with the state names
plt.show()
sns.set()

# %%
# Transposing the dataset 
tdfPercentageGrowth = dfPercentageGrowth.transpose()

# When transposing, the first column of the inital dataframe becomes the first row of the transposed dataframe
# Code to move the first rows of dataframe as column headers and drop first row
tdfPercentageGrowth.columns = tdfPercentageGrowth.iloc[0]
tdfPercentageGrowth = tdfPercentageGrowth.drop(tdfPercentageGrowth.index[0])

# Typecasting the data from string (object) to type int
tdfPercentageGrowth = tdfPercentageGrowth.astype(str).astype(float)
tdfPercentageGrowth['Average_Percentage_Growth'] = tdfPercentageGrowth.mean(axis = 1)

# Making the index a new column and re-indexing the pandas dataframe
tdfPercentageGrowth['States'] = tdfPercentageGrowth.index
tdfPercentageGrowth.reset_index(inplace = True, drop = True)

# Printing the dataset for sense check
tdfPercentageGrowth.head()
# Out:
# Duration  2012-13  2013-14  2014-15  2015-16  Average_Percentage_Growth  \
# 0            8.43    12.85    13.40    15.85                    12.6325
# 1           13.41    16.38    14.79    12.07                    14.1625
# 2            9.56    13.31    11.45    13.19                    11.8775
# 3           14.25    12.30    17.92    10.59                    13.7650
# 4           12.30    16.44    13.69    10.98                    13.3525
#
# Duration             States
# 0           Andhra Pradesh
# 1         Arunachal Pradesh
# 2                     Assam
# 3                     Bihar
# 4              Chhattisgarh

# %%
# Sorting absolute Current Prices values
tdfPercentageGrowth = tdfPercentageGrowth.sort_values(['Average_Percentage_Growth']).reset_index(drop = True)

# Specifying the values of x-axis and y-axis
x = tdfPercentageGrowth.States
y = tdfPercentageGrowth.Average_Percentage_Growth
sns.set(style="white")

# Deciding the size of the graph to be plotted 
fig, ax = plt.subplots(figsize=(30,10))

# Rotating the State names by 45 degrees to make it easier to view
ax1 = sns.barplot(x, y, color='#004488')
ax1.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# Displaying the plot along with the state names
plt.show()
sns.set()

# %% [markdown]
# ### Best fit line for % growth of States

# %%
# Sorting absolute Current Prices values
tdfPercentageGrowth = tdfPercentageGrowth.sort_values(['Average_Percentage_Growth']).reset_index(drop = True)

x = tdfPercentageGrowth.States
y = tdfPercentageGrowth.Average_Percentage_Growth
sns.set(style="white", rc={"lines.linewidth": 3})

fig, ax1 = plt.subplots(figsize=(30,10))
ax2 = ax1.twinx()

# Bar plot
sns.barplot(x, y, color='#004488', ax=ax1)
ax1 = sns.lineplot(x, y, color='r', marker="o")
ax1.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# plt.tight_layout()

plt.show()
sns.set()

# %% [markdown]
# Post the cleaning of data and analysis of the same, we shall now proceed to answer the following questions:
#
# 1. How will you compare the growth rates of any two states?
#      - We can compare the growth rate of any 2 states by looking at the plots of the % growth over the years. An accurate representation of the same can be found using the % Growth average, state-wise.
#
#
# 2. Which states have been growing consistently fast, and which ones have been struggling? Rank top 3 fastest and 3 slowest-growing states.
#     - We shall use the bar plots for this analysis.
#     The top 3 states in terms of growth have been:
#     1. Mizoram
#     2. Nagaland
#     3. Tripura
#
#     and, the bottom 3 states that have been struggling:
#     1. Goa
#     2. Meghalaya
#     3. Sikkim
#
#
# 3. What is the Nation's Growth Rate?
#     -
#
# 4. What has been the average growth rate of your home state, and how does it compare to the national average?
#     -

# %% [markdown]
# Now that we have answered the above questions, we shall now proceed to perform the following analysis:
# #### Plot the total GDP of the states for the year 2015-16:
# 1. Which Plot will you use for this? Why? (Remeber to plot the graph in a way such as it is easier to read and compare)
#
# 2. Identify the top 5 and the bottom 5 states based on total GDP.
#
# 3. What insights can you draw from this graph? What states are performing poorly? (Remember: this will not be solely based on total GDP)

# %% [markdown]
# ### Part I-B
#
# <i>Note: The analysis is to be done for the years of 2014-15</i>
#
# The analysis is to be formed for Indian States (exclusing union territories)
#
# Following are the steps to be followed:
# - Plot the GDP per capita for all the states.
#      - Identify the top 5 and the bottom 5 states based on the GDP per capita.
#      - Find the ratio of the highest per capita GDP to the lowest per capita GDP.
#
#
# - Plot the percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states.
#     - Which plot will you use here? Why?
#     - Why is (Primary + Secondary + Tertiary) not equal to total GDP?
#     - Can you draw any insight from this? Find correlation of percentile of the state (% of states with lower GDP) and %contribution of Primary sector to total GDP.
#
#
# - Categorise the states into four groups based on the GDP per capita (C1, C2, C3, C4, where C1 would have the highest per capita GDP and C4, the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e., the states lying between the 85th and the 100th percentile are in C1; those between the 50th and the 85th percentiles are in C2, and so on.
#
# For each category (C1, C2, C3, C4):
# Find the top 3/4/5 sub-sectors (such as agriculture, forestry and fishing, crops, manufacturing etc., not primary, secondary and tertiary) that contribute to approximately 80% of the GSDP of each category.
#
#     - Note-I: The nomenclature for this project is as follows: primary, secondary and tertiary are named 'sectors', while agriculture, manufacturing etc. are named 'sub-sectors'.
#
#     - Note-II: If the top 3 sub-sectors contribute to, say, 79% of the GDP of some category, you can report "These top 3 sub-sectors contribute to approximately 80% of the GDP". This is to simplify the analysis and make the results consumable. (Remember, the CEO has to present the report to the CMs, and CMs have limited time; so, the analysis needs to be sharp and concise.)
#
# Plot the contribution of the sub-sectors as a percentage of the GSDP of each category.

# %% [markdown]
# Now that you have summarised the data in the form of plots, tables, etc., try to draw non-obvious insights from it. Think about questions such as:
#
# - How does the GDP distribution of the top states (C1) differ from the others?
# - Which sub-sectors seem to be correlated with high GDP?
# - Which sub-sectors do the various categories need to focus on?
#
# Ask other such relevant questions, which you think are important, and note your insights for category separately. More insights are welcome and will be awarded accordingly.
#
# Finally, provide at least two recommendations for each category to improve the per capita GDP.

# %% [markdown]
# ### Part-II: GDP and Education Dropout Rates
#
# In Part-I, you would have noticed that (one) way to increase per capita GDP is by shifting the distribution of GDP towards the secondary and tertiary sectors, i.e., the manufacturing and services industries. But these industries can thrive only when there is an availability of educated and skilled labour.
#
# In this part of the analysis, you will investigate whether there is any relationship between per capita GDP with dropout rates in education.

# %% [markdown]
# - Analyse if there is any correlation of GDP per capita with dropout rates in education (primary, upper primary and secondary) for the year 2014-2015 for each state. Choose an appropriate plot to conduct this analysis.
#     - Is there any correlation between dropout rate and %contribution of each sector (Primary, Secondary and Tertiary) to the total GDP?
#
#
# - You have the total population of each state from the data in part I. Is there any correlation between dropout rates and population? What is the expected trend and what is the observation?
#
#
# - Write down the key insights you draw from this data:
#     - Form at least one reasonable hypothesis for the observations from the data
