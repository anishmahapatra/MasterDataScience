# %% [markdown]
# ## Data Cleaning-II
#
# ### Description
# In the given dataset, you have to do the following:
# - Remove rows with more than 2 missing values --done
# - Remove any column having the same value for all rows --done
# - Normalize all numerical columns(check for integer and float columns)
# - Drop duplicate rows --done
# - Determine invalid values in the 'Year' column(assume every input dataframe will have an year column and an
#                                               invalid year would be more than 2018 and less than 1900). --done
# (Remember to calculate this before normalizing columns since Year will be a numeric column)
#
# <b><i>Note<i></b>: you simply have to determine invalid values and not delete the
#
# ### Input format:
# The input will only contain the URL of a csv file. The import statement has been written for you in the stub
#
# ### Output format:
# The first line will have number of invalid values in the year column
# The second line will have the number of rows in the resulting dataframe
# The third line will have number of columns in the resulting dataframe
# The fourth line will have first three rows of the resulting dataframe
#
# <b>Note</b>: You can refer to the sample testcase for a sample dataframe URL and sample output.
#     You can try the code on your own Jupyter notebook before submitting.

# %%
import pandas as pd 
pd.set_option('display.max_columns', 500)
import numpy as np

# %%
# Resding the Admission_Predict csv
df = pd.read_csv("titanicmod.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Year     Ship  \
# 0  34.5      0      0   330911   7.8292   NaN        Q  1927  Titanic
# 1  47.0      1      0   363272   7.0000   NaN        S  2020  Titanic
# 2  62.0      0      0   240276   9.6875   NaN        Q  1990  Titanic
# 3  27.0      0      0   315154   8.6625   NaN        S  1915  Titanic
# 4  22.0      1      1  3101298  12.2875   NaN        S  1933  Titanic
#
#   Movie Director
# 0  James Cameron
# 1  James Cameron
# 2  James Cameron
# 3  James Cameron
# 4  James Cameron

# %%
df.shape
# Out:
# (418, 14)

# %%
# FInding the number of missing values in the dataset
df.isnull().sum()
# Out:
# PassengerId         0
# Pclass              0
# Name                0
# Sex                 0
# Age                86
# SibSp               0
# Parch               0
# Ticket              0
# Fare                1
# Cabin             327
# Embarked            0
# Year                0
# Ship                0
# Movie Director      0
# dtype: int64

# %% [markdown]
# Here, we realize that there are missing values in the dataset
# We shall now proceed to remove rows that have more than 2 null values.
#
# The number of non-na values expected is 7/9

# %% [markdown]
# This will keep only rows which have nan's less than 7 in the dataframe, and will remove all having nan's > 7.

# %%
# This will keep the rows that have 2 NaNs or less
df = df[df.isnull().sum(axis=1) < 3]
df.shape
# Out:
# (418, 14)

# %%
# Removing the columns that have the same value throughtout
nunique = df.apply(pd.Series.nunique)
cols_to_drop = nunique[nunique == 1].index
df.drop(cols_to_drop, axis=1)
df.shape
# Out:
# (418, 14)

# %%
# Dropping duplicate values
df.drop_duplicates(keep=False, inplace=True)
df.shape
# Out:
# (418, 14)

# %%
# Subsetting the invalid years into a list invalidYearToList
df1 = df
dfInvalidYears = df1.loc[(df1['Year'] > 2018) | (df1['Year'] < 1900)]
invalidYearToList = dfInvalidYears['Year'].tolist()
invalidYearToList
# Out:
# [2020,
#  1886,
#  1899,
#  2024,
#  2021,
#  1896,
#  1890,
#  1898,
#  1885,
#  1890,
#  1880,
#  1886,
#  1884,
#  2020,
#  1893,
#  2020,
#  1882,
#  2023,
#  1887,
#  1891,
#  1895,
#  2022,
#  2020,
#  2022,
#  1896,
#  2020,
#  1886,
#  2023,
#  1886,
#  1896,
#  2020,
#  1898,
#  2022,
#  1891,
#  1893,
#  1894,
#  1899,
#  1895,
#  1884,
#  1883,
#  1896,
#  1880,
#  2021,
#  1895,
#  1892,
#  1896,
#  1886,
#  2022,
#  1899,
#  1897,
#  1886,
#  1888,
#  1884,
#  1899,
#  1890,
#  1888,
#  1883,
#  2020,
#  2019,
#  1891,
#  2019,
#  2022,
#  2019,
#  1892,
#  1891,
#  1887,
#  1882,
#  1880,
#  1890,
#  1882,
#  1892,
#  1880,
#  1893,
#  1891,
#  2023,
#  1891,
#  2023,
#  1898,
#  1897,
#  1899,
#  1897,
#  1892,
#  1897,
#  1893,
#  1885,
#  1884,
#  1896,
#  2024,
#  1890,
#  1897,
#  1885]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Year', 'Ship',
#        'Movie Director'],
#       dtype='object')

# %%
df_num = df.select_dtypes(include=[np.number])
df_norm = (df_num - df_num.mean()) / (df_num.max() - df_num.min())
df[df_norm.columns] = df_norm
df
# Out:
#      PassengerId    Pclass                                               Name  \
# 0      -0.500000  0.367225                                   Kelly, Mr. James
# 1      -0.497602  0.367225                   Wilkes, Mrs. James (Ellen Needs)
# 2      -0.495204 -0.132775                          Myles, Mr. Thomas Francis
# 3      -0.492806  0.367225                                   Wirz, Mr. Albert
# 4      -0.490408  0.367225       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5      -0.488010  0.367225                         Svensson, Mr. Johan Cervin
# 6      -0.485612  0.367225                               Connolly, Miss. Kate
# 7      -0.483213 -0.132775                       Caldwell, Mr. Albert Francis
# 8      -0.480815  0.367225          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9      -0.478417  0.367225                            Davies, Mr. John Samuel
# 10     -0.476019  0.367225                                   Ilieff, Mr. Ylio
# 11     -0.473621 -0.632775                         Jones, Mr. Charles Cresson
# 12     -0.471223 -0.632775      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13     -0.468825 -0.132775                               Howard, Mr. Benjamin
# 14     -0.466427 -0.632775  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15     -0.464029 -0.132775      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 16     -0.461631 -0.132775                                  Keane, Mr. Daniel
# 17     -0.459233  0.367225                                  Assaf, Mr. Gerios
# 18     -0.456835  0.367225                       Ilmakangas, Miss. Ida Livija
# 19     -0.454436  0.367225              Assaf Khalil, Mrs. Mariana (Miriam")"
# 20     -0.452038 -0.632775                             Rothschild, Mr. Martin
# 21     -0.449640  0.367225                          Olsen, Master. Artur Karl
# 22     -0.447242 -0.632775               Flegenheim, Mrs. Alfred (Antoinette)
# 23     -0.444844 -0.632775                    Williams, Mr. Richard Norris II
# 24     -0.442446 -0.632775    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25     -0.440048  0.367225                            Robins, Mr. Alexander A
# 26     -0.437650 -0.632775                       Ostby, Miss. Helene Ragnhild
# 27     -0.435252  0.367225                                  Daher, Mr. Shedid
# 28     -0.432854 -0.632775                            Brady, Mr. John Bertram
# 29     -0.430456  0.367225                                  Samaan, Mr. Elias
# ..           ...       ...                                                ...
# 388     0.430456  0.367225                               Canavan, Mr. Patrick
# 389     0.432854  0.367225                        Palsson, Master. Paul Folke
# 390     0.435252 -0.632775                         Payne, Mr. Vivian Ponsonby
# 391     0.437650 -0.632775     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 392     0.440048  0.367225                      Abbott, Master. Eugene Joseph
# 393     0.442446 -0.132775                               Gilbert, Mr. William
# 394     0.444844  0.367225                           Kink-Heilmann, Mr. Anton
# 395     0.447242 -0.632775     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 396     0.449640  0.367225                               Colbert, Mr. Patrick
# 397     0.452038 -0.632775  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 398     0.454436  0.367225                     Larsson-Rondberg, Mr. Edvard A
# 399     0.456835  0.367225                           Conlon, Mr. Thomas Henry
# 400     0.459233 -0.632775                            Bonnell, Miss. Caroline
# 401     0.461631 -0.132775                                    Gale, Mr. Harry
# 402     0.464029 -0.632775                     Gibson, Miss. Dorothy Winifred
# 403     0.466427 -0.632775                             Carrau, Mr. Jose Pedro
# 404     0.468825 -0.632775                       Frauenthal, Mr. Isaac Gerald
# 405     0.471223 -0.132775       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406     0.473621 -0.132775                          Ware, Mr. William Jeffery
# 407     0.476019 -0.632775                         Widener, Mr. George Dunton
# 408     0.478417  0.367225                    Riordan, Miss. Johanna Hannah""
# 409     0.480815  0.367225                          Peacock, Miss. Treasteall
# 410     0.483213  0.367225                             Naughton, Miss. Hannah
# 411     0.485612 -0.632775    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412     0.488010  0.367225                     Henriksson, Miss. Jenny Lovisa
# 413     0.490408  0.367225                                 Spector, Mr. Woolf
# 414     0.492806 -0.632775                       Oliva y Ocana, Dona. Fermina
# 415     0.495204  0.367225                       Saether, Mr. Simon Sivertsen
# 416     0.497602  0.367225                                Ware, Mr. Frederick
# 417     0.500000  0.367225                           Peter, Master. Michael J
#
#         Sex       Age     SibSp     Parch              Ticket      Fare  \
# 0      male  0.055749 -0.055921 -0.043594              330911 -0.054258
# 1    female  0.220591  0.069079 -0.043594              363272 -0.055877
# 2      male  0.418402 -0.055921 -0.043594              240276 -0.050631
# 3      male -0.043157 -0.055921 -0.043594              315154 -0.052632
# 4    female -0.109094  0.069079  0.067517             3101298 -0.045556
# 5      male -0.214593 -0.055921 -0.043594                7538 -0.051534
# 6    female -0.003595 -0.055921 -0.043594              330972 -0.054648
# 7      male -0.056344  0.069079  0.067517              248738 -0.012935
# 8    female -0.161843 -0.055921 -0.043594                2657 -0.055429
# 9      male -0.122281  0.194079 -0.043594           A/4 48871 -0.022402
# 10     male       NaN -0.055921 -0.043594              349220 -0.054128
# 11     male  0.207404 -0.055921 -0.043594                 694 -0.018791
# 12   female -0.095907  0.069079 -0.043594               21228  0.091034
# 13     male  0.431589  0.069079 -0.043594               24065 -0.018791
# 14   female  0.220591  0.069079 -0.043594         W.E.P. 5734  0.049866
# 15   female -0.082719  0.069079 -0.043594       SC/PARIS 2167 -0.015432
# 16     male  0.062342 -0.055921 -0.043594              233734 -0.045434
# 17     male -0.122281 -0.055921 -0.043594                2692 -0.055437
# 18   female -0.043157  0.069079 -0.043594    STON/O2. 3101270 -0.054071
# 19   female  0.194216 -0.055921 -0.043594                2696 -0.055437
# 20     male  0.326090  0.069079 -0.043594            PC 17603  0.046401
# 21     male -0.280530 -0.055921  0.067517             C 17368 -0.063351
# 22   female       NaN -0.055921 -0.043594            PC 17598 -0.007698
# 23     male -0.122281 -0.055921  0.067517            PC 17597  0.050265
# 24   female  0.233778  0.069079  0.289740            PC 17608  0.442582
# 25     male  0.260153  0.069079 -0.043594           A/5. 3337 -0.041238
# 26   female -0.109094 -0.055921  0.067517              113509  0.051436
# 27     male -0.102500 -0.055921 -0.043594                2698 -0.055437
# 28     male  0.141467 -0.055921 -0.043594              113054 -0.010008
# 29     male       NaN  0.194079 -0.043594                2662 -0.027225
# ..      ...       ...       ...       ...                 ...       ...
# 388    male -0.122281 -0.055921 -0.043594              364858 -0.054413
# 389    male -0.320092  0.319079  0.067517              349909 -0.028404
# 390    male -0.095907 -0.055921 -0.043594               12749  0.112960
# 391  female  0.273340 -0.055921  0.067517            PC 17592  0.007364
# 392    male -0.227780 -0.055921  0.178628           C.A. 2673 -0.030014
# 393    male  0.220591 -0.055921 -0.043594          C.A. 30769 -0.049045
# 394    male -0.016782  0.319079  0.067517              315153 -0.026550
# 395  female -0.161843  0.069079 -0.043594               13695  0.047573
# 396    male -0.082719 -0.055921 -0.043594              371109 -0.055389
# 397  female  0.233778  0.069079  0.067517               13567  0.085048
# 398    male -0.109094 -0.055921 -0.043594              347065 -0.054364
# 399    male  0.009593 -0.055921 -0.043594               21332 -0.054445
# 400  female -0.003595 -0.055921 -0.043594               36928  0.252259
# 401    male  0.101904  0.069079 -0.043594               28664 -0.028550
# 402  female -0.109094 -0.055921  0.067517              112378  0.046401
# 403    male -0.175031 -0.055921 -0.043594              113059  0.022393
# 404    male  0.167841  0.069079 -0.043594               17765 -0.015432
# 405    male -0.135469 -0.055921 -0.043594       SC/PARIS 2166 -0.042482
# 406    male -0.095907  0.069079 -0.043594               28666 -0.049045
# 407    male  0.260153  0.069079  0.067517              113503  0.343281
# 408  female       NaN -0.055921 -0.043594              334915 -0.054470
# 409  female -0.359654  0.069079  0.067517  SOTON/O.Q. 3101315 -0.042653
# 410  female       NaN -0.055921 -0.043594              365237 -0.054413
# 411  female  0.088717  0.069079 -0.043594               19928  0.106129
# 412  female -0.029970 -0.055921 -0.043594              347086 -0.054364
# 413    male       NaN -0.055921 -0.043594           A.5. 3236 -0.053827
# 414  female  0.115092 -0.055921 -0.043594            PC 17758  0.143019
# 415    male  0.108498 -0.055921 -0.043594  SOTON/O.Q. 3101262 -0.055389
# 416    male       NaN -0.055921 -0.043594              359309 -0.053827
# 417    male       NaN  0.069079  0.067517                2668 -0.025899
#
#                Cabin Embarked      Year     Ship Movie Director
# 0                NaN        Q -0.170471  Titanic  James Cameron
# 1                NaN        S  0.475362  Titanic  James Cameron
# 2                NaN        Q  0.267029  Titanic  James Cameron
# 3                NaN        S -0.253804  Titanic  James Cameron
# 4                NaN        S -0.128804  Titanic  James Cameron
# 5                NaN        S -0.239916  Titanic  James Cameron
# 6                NaN        Q -0.455193  Titanic  James Cameron
# 7                NaN        S  0.308696  Titanic  James Cameron
# 8                NaN        C  0.232307  Titanic  James Cameron
# 9                NaN        S -0.073249  Titanic  James Cameron
# 10               NaN        S  0.176751  Titanic  James Cameron
# 11               NaN        S -0.253804  Titanic  James Cameron
# 12               B45        S -0.253804  Titanic  James Cameron
# 13               NaN        S -0.073249  Titanic  James Cameron
# 14               E31        S -0.364916  Titanic  James Cameron
# 15               NaN        C -0.038527  Titanic  James Cameron
# 16               NaN        Q  0.503140  Titanic  James Cameron
# 17               NaN        C  0.482307  Titanic  James Cameron
# 18               NaN        S -0.385749  Titanic  James Cameron
# 19               NaN        C  0.148973  Titanic  James Cameron
# 20               NaN        C  0.086473  Titanic  James Cameron
# 21               NaN        S  0.079529  Titanic  James Cameron
# 22               NaN        S  0.392029  Titanic  James Cameron
# 23               NaN        C  0.294807  Titanic  James Cameron
# 24   B57 B59 B63 B66        C  0.253140  Titanic  James Cameron
# 25               NaN        S  0.280918  Titanic  James Cameron
# 26               B36        C  0.329529  Titanic  James Cameron
# 27               NaN        C -0.427416  Titanic  James Cameron
# 28               A21        S -0.260749  Titanic  James Cameron
# 29               NaN        C  0.225362  Titanic  James Cameron
# ..               ...      ...       ...      ...            ...
# 388              NaN        Q -0.337138  Titanic  James Cameron
# 389              NaN        S  0.454529  Titanic  James Cameron
# 390              B24        S -0.385749  Titanic  James Cameron
# 391              D28        S -0.309360  Titanic  James Cameron
# 392              NaN        S  0.385084  Titanic  James Cameron
# 393              NaN        S  0.065640  Titanic  James Cameron
# 394              NaN        S  0.503140  Titanic  James Cameron
# 395              C31        S -0.107971  Titanic  James Cameron
# 396              NaN        Q -0.107971  Titanic  James Cameron
# 397              B41        C -0.239916  Titanic  James Cameron
# 398              NaN        S -0.010749  Titanic  James Cameron
# 399              NaN        Q -0.330193  Titanic  James Cameron
# 400               C7        S -0.302416  Titanic  James Cameron
# 401              NaN        S  0.239251  Titanic  James Cameron
# 402              NaN        C  0.371196  Titanic  James Cameron
# 403              NaN        S -0.038527  Titanic  James Cameron
# 404              D40        C  0.419807  Titanic  James Cameron
# 405              D38        C  0.030918  Titanic  James Cameron
# 406              NaN        S  0.336473  Titanic  James Cameron
# 407              C80        C  0.378140  Titanic  James Cameron
# 408              NaN        Q -0.198249  Titanic  James Cameron
# 409              NaN        S -0.107971  Titanic  James Cameron
# 410              NaN        Q -0.024638  Titanic  James Cameron
# 411              C78        Q -0.427416  Titanic  James Cameron
# 412              NaN        S -0.177416  Titanic  James Cameron
# 413              NaN        S  0.183696  Titanic  James Cameron
# 414             C105        C -0.378804  Titanic  James Cameron
# 415              NaN        S  0.350362  Titanic  James Cameron
# 416              NaN        S -0.031582  Titanic  James Cameron
# 417              NaN        C -0.462138  Titanic  James Cameron
#
# [418 rows x 14 columns]

# %%
df.shape
# Out:
# (418, 14)

# %%
df.shape[0]
# Out:
# 418

# %%
df = pd.read_csv("currencies.csv")

# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
# df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# E:\Miniconda\envs\ipykernel\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col0 {
#             background-color:  #b40426;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col1 {
#             background-color:  #e1dad6;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col2 {
#             background-color:  #ead5c9;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col3 {
#             background-color:  #e9d5cb;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col4 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col5 {
#             background-color:  #dc5d4a;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col6 {
#             background-color:  #cfdaea;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col7 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col8 {
#             background-color:  #f7ad90;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col9 {
#             background-color:  #f2cbb7;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col10 {
#             background-color:  #f7b599;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col11 {
#             background-color:  #a3c2fe;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col12 {
#             background-color:  #d3dbe7;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col13 {
#             background-color:  #c3d5f4;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col14 {
#             background-color:  #e8d6cc;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col15 {
#             background-color:  #e7d7ce;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col16 {
#             background-color:  #c1d4f4;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col17 {
#             background-color:  #efcfbf;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col18 {
#             background-color:  #f7b093;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col19 {
#             background-color:  #a2c1ff;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col20 {
#             background-color:  #ccd9ed;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col21 {
#             background-color:  #3b4cc0;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col22 {
#             background-color:  #efcebd;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col23 {
#             background-color:  #ecd3c5;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col24 {
#             background-color:  #f4987a;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col25 {
#             background-color:  #b5cdfa;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col26 {
#             background-color:  #d7dce3;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col27 {
#             background-color:  #d3dbe7;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col28 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col29 {
#             background-color:  #d55042;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col30 {
#             background-color:  #e8765c;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col31 {
#             background-color:  #e2dad5;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col32 {
#             background-color:  #f7b497;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col33 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col34 {
#             background-color:  #e7d7ce;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col35 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col36 {
#             background-color:  #f7b599;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col37 {
#             background-color:  #f4c6af;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col38 {
#             background-color:  #f1ccb8;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col39 {
#             background-color:  #cad8ef;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col40 {
#             background-color:  #c1d4f4;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col41 {
#             background-color:  #f39778;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col42 {
#             background-color:  #efcebd;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col43 {
#             background-color:  #f29274;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col44 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col45 {
#             background-color:  #f7a98b;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row0_col46 {
#             background-color:  #f1cdba;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col0 {
#             background-color:  #b7cff9;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col1 {
#             background-color:  #b40426;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col2 {
#             background-color:  #6f92f3;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col3 {
#             background-color:  #f39475;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col4 {
#             background-color:  #9fbfff;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col5 {
#             background-color:  #e3d9d3;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col6 {
#             background-color:  #f2cbb7;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col7 {
#             background-color:  #9fbfff;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col8 {
#             background-color:  #f7ad90;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col9 {
#             background-color:  #f5c1a9;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col10 {
#             background-color:  #c5d6f2;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col11 {
#             background-color:  #ef886b;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col12 {
#             background-color:  #efcfbf;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col13 {
#             background-color:  #be242e;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col14 {
#             background-color:  #b40426;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col15 {
#             background-color:  #f49a7b;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col16 {
#             background-color:  #f7b497;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col17 {
#             background-color:  #e8d6cc;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col18 {
#             background-color:  #ed8366;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col19 {
#             background-color:  #82a6fb;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col20 {
#             background-color:  #bed2f6;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col21 {
#             background-color:  #3b4cc0;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col22 {
#             background-color:  #f7aa8c;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col23 {
#             background-color:  #9bbcff;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col24 {
#             background-color:  #f6bfa6;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col25 {
#             background-color:  #e8d6cc;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col26 {
#             background-color:  #d9dce1;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col27 {
#             background-color:  #d1493f;
#         }    #T_90098d5c_012b_11ea_93b8_f430b9aee9c3row1_col28 {
#             background-color:  #9fbfff;
#         }    #T_90098d5

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install Jinja2
# Out:
# Collecting Jinja2
#   Downloading https://files.pythonhosted.org/packages/65/e0/eb35e762802015cab1ccee04e8a277b03f1d8e53da3ec3106882ec42558b/Jinja2-2.10.3-py2.py3-none-any.whl (125kB)
# Collecting MarkupSafe>=0.23 (from Jinja2)
#   Downloading https://files.pythonhosted.org/packages/65/c6/2399700d236d1dd681af8aebff1725558cddfd6e43d7a5184a675f4711f5/MarkupSafe-1.1.1-cp37-cp37m-win_amd64.whl
# Installing collected packages: MarkupSafe, Jinja2
# Successfully installed Jinja2-2.10.3 MarkupSafe-1.1.1
